# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIRAM199/my_practice/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Agenda
#
# ### 1. Setting Up the Environment in Google Colab
#    - Downloading and Organizing CSV Files
#    - Importing Pandas in Google Colab
#    - Reading and Understanding Data
#
#
# ### 2. Pandas Tutorial
#   - Data Frame(DF)
#      - Data Frame Operations
#   - Series
#      - Series Operations
#   - Understanding loc and iloc
#   - Basic Operations in Pandas
#       - Filtering Data
#       - Grouping Data
#       - Sorting Data
#       - String Operations
#       - Resetting Index
#   - Restructuring Data with Melt
#   - Applying Custom Functions in Pandas
#
# ### 3. Creating Series and DataFrames from Scratch
#    - Creating a Series
#    - Creating a DataFrame
#    - Concatenating a Dataframe
#
#
# ### 4. Dealing with Missing Values
#    - General Knowledge on Reading CSV files
#    - Understanding Missing Values
#    - Strategies for Handling Missing Data
#       - Deletion Methods
#       - Imputation Methods
#
# ### 5.Exploratory Data Analysis (EDA)
#    - Data Cleaning and Manipulation
#    - Working with DateTime

# %% [markdown]
# # Setting Up Your Environment

# %% [markdown]
# ## Downloading and Organizing CSV Files
# -  Create a folder in Google Collab with the name **DataScienceCourse**, making it easy to manage and access notebooks.
# - Import the given **[gapminder.csv](https://www.kaggle.com/datasets/albertovidalrod/gapminder-dataset)**, **[disease.csv](https://github.com/kb22/Heart-Disease-Prediction/raw/master/dataset.csv)** and **[weather.csv](https://github.com/yesdhruv/csv_files/blob/master/weather.csv)** files and upload it to  Google Collab in the DataScienceCourse Folder as we will be using these.

# %% [markdown]
# ## Importing Pandas in Google Colab
# Make sure that Pandas is available in your Colab environment. If not we can use the below command:

# %%
# !pip install pandas

# %% [markdown]
# After installing let's import pandas. It's a standard practice to use **pd** for using the pandas functions.

# %%
import pandas as pd

# %% [markdown]
# ## Reading and Understanding Data
# * Overview of the Gapminder Dataset
#  * The Gapminder dataset is a comprehensive repository of global development metrics, offering a nuanced view of societal progress. Renowned for its use in captivating TED Talks by Hans Rosling, this dataset encapsulates key indicators such as life expectancy, GDP per capita, and population across diverse countries and years.
#
# - Import the 'gapminder.csv' file directly from github url or you do the upload method taht weit using the steps discussed above

# %%
# PANDAS:

# excel
# text
# csv
# json
# parquet
# ...
# ...
# ...

# READING FROM OUR LOCAL MACHINE....

# pandas_dataframe=pd.read_excel("path of the file.xlsx")
# pandas_dataframe=pd.read_csv(".csv")
# pandas_dataframe=pd.read_json(".json")


# WE COULD ALSO READ DATA FROM PUBLIC LOCATIONS--> raw_github

# %%
# Use the correct raw URL for the CSV file on GitHub
csv_url = 'https://raw.githubusercontent.com/yesdhruv/gapminder.csv/master/gapminder_data_graphs.csv'

# %%
df = pd.read_csv(csv_url)
# Display the DataFrame
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
df.shape
# Out:
# (3675, 8)

# %% [markdown]
# The above code will display a 2-dimensional labeled structure with diverse data types and as we can see the 3675 rows with 8 columns which represents the size of the data frame.
# Pandas give each row a number (starting from 0) in the 'gapminder.csv' DataFrame.
# The table shows column names at the top, including data like country names and numbers.

# %% [markdown]
# # Pandas Tutorial
# Pandas is a powerful and user-friendly Python library that simplifies data manipulation and analysis. Pandas helps in organizing, cleaning, and analyzing the data seamlessly.

# %%
df.loc[2,'life_exp']
# Out:
# np.float64(54.7)

# %%
df.loc[3,]
# Out:
# country        Afghanistan
# continent             Asia
# year                  2001
# life_exp              54.8
# hdi_index            0.353
# co2_consump         0.0376
# gdp                    NaN
# services              24.7
# Name: 3, dtype: object

# %%
df.iloc[2,2]
# Out:
# np.int64(2000)

# %%
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %% [markdown]
#  ### Data Frame (DF)
#   In pandas, a Data Frame represents a table and is the default storage structure for tabular data. Tables created by reading CSV files, like DF = pd.read_csv('file.csv'), are stored as Data Frames.
#
# * Usage
#
#    * Accessing Rows: You can access rows using df.loc[]. For example, df.loc[0] retrieves the first row of the DataFrame df.
#    * Row as Series: When accessing a single row, it is returned as a Series, not a DataFrame
#
# **Note:** Data Frames can handle diverse data types, providing versatility beyond numeric values

# %% [markdown]
# #### DataFrame Operations
#
# 1. Creating a DataFrame- Data is read from a CSV file and stored in a variable, typically named DF (short for DataFrame).

# %%
# storing the file content in DF variable
import pandas as pd
DF = pd.read_csv(csv_url)

# %% [markdown]
# 2. Printing the DataFrame:
# Writing DF in a cell and executing it will display the DataFrame in Google Colab.

# %%
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %% [markdown]
# 3. Viewing Top Rows (head):
# DF.head() displays the top five rows of the DataFrame by default.
# Inorder to display specific number of rows we can pass it to the header parameter.

# %%
# UNDERSTANDING THE DATA

# %%
DF.shape
# Out:
# (3675, 8)

# %%
DF.head(25)
# Out:
#         country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0   Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1   Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2   Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3   Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4   Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# 5   Afghanistan      Asia  2003      56.5      0.393       0.0509   346.0
# 6   Afghanistan      Asia  2004      57.1      0.409       0.0368   336.0
# 7   Afghanistan      Asia  2005      57.6      0.418       0.0515   360.0
# 8   Afghanistan      Asia  2006      58.0      0.429       0.0622   368.0
# 9   Afghanistan      Asia  2007      58.5      0.447       0.0838   409.0
# 10  Afghanistan      Asia  2008      59.2      0.447       0.1520   415.0
# 11  Afghanistan      Asia  2009      59.9      0.460       0.2380   492.0
# ...

# %%
DF.head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6

# %%
DF.tail()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3670  Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671  Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672  Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673  Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674  Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2

# %%
DF.tail(25)
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3650    Zambia    Africa  2015      60.8      0.569        0.271  1340.0
# 3651    Zambia    Africa  2016      61.4      0.571        0.296  1350.0
# 3652    Zambia    Africa  2017      61.9      0.578        0.304  1350.0
# 3653    Zambia    Africa  2018      62.5      0.582        0.302  1370.0
# 3654  Zimbabwe    Africa  1998      49.7      0.442        1.200  1780.0
# 3655  Zimbabwe    Africa  1999      48.5      0.437        1.330  1760.0
# 3656  Zimbabwe    Africa  2000      47.5      0.430        1.160  1700.0
# 3657  Zimbabwe    Africa  2001      47.0      0.431        1.050  1720.0
# 3658  Zimbabwe    Africa  2002      46.6      0.423        0.996  1560.0
# 3659  Zimbabwe    Africa  2003      46.4      0.414        0.886  1290.0
# 3660  Zimbabwe    Africa  2004      46.4      0.411        0.785  1210.0
# 3661  Zimbabwe    Africa  2005      46.8      0.411        0.887  1140.0
# ...

# %%
# fetching the first top ten rows
DF.head(10)
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 5  Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
# 6  Afghanistan      Asia  2004      57.1      0.409       0.0368  336.0
# 7  Afghanistan      Asia  2005      57.6      0.418       0.0515  360.0
# 8  Afghanistan      Asia  2006      58.0      0.429       0.0622  368.0
# 9  Afghanistan      Asia  2007      58.5      0.447       0.0838  409.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6
# 5      25.9
# 6      26.1
# 7      26.5
# 8      26.9
# 9      27.7

# %% [markdown]
# 4. Viewing Bottom Rows (tail):
# DF.tail() shows the last few rows of the DataFrame.
# Similar to head, we can specify the number of rows, e.g., DF.tail(3).

# %%
# fetching the last ten rows
DF.tail(10)
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3665  Zimbabwe    Africa  2009      50.2      0.458        0.441   941.0
# 3666  Zimbabwe    Africa  2010      52.3      0.482        0.607  1110.0
# 3667  Zimbabwe    Africa  2011      54.4      0.499        0.737  1250.0
# 3668  Zimbabwe    Africa  2012      56.0      0.525        0.587  1430.0
# 3669  Zimbabwe    Africa  2013      57.2      0.537        0.872  1440.0
# 3670  Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671  Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672  Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673  Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674  Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 3665      24.8
# 3666      25.2
# 3667      25.0
# 3668      25.4
# 3669      25.3
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# ...

# %% [markdown]
# 5. DataFrame Type (type):
# Used to check the DataFrame's type, which should be pandas.core.frame.DataFrame.

# %%
type(DF)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 6. DataFrame Shape (shape):
# DF.shape returns the dimensions of the DataFrame

# %%
DF.shape
# Out:
# (3675, 8)

# %% [markdown]
# 7. DataFrame Info (info):
# DF.info() provides a summary of the DataFrame, including the number of non-null values and data types of each column.

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3675 entries, 0 to 3674
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      3675 non-null   object
#  1   continent    3675 non-null   object
#  2   year         3675 non-null   int64
#  3   life_exp     3675 non-null   float64
#  4   hdi_index    3563 non-null   float64
#  5   co2_consump  3671 non-null   float64
#  6   gdp          3633 non-null   float64
#  7   services     3675 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 229.8+ KB

# %% [markdown]
# **Note:** Use .shape and .info() methods to understand the Dataframe's structure and data types.

# %% [markdown]
# 8. DataFrame Describe (describe):
# DF.describe() offers a statistical summary of numerical columns, including count, mean, standard deviation, min/max values, and percentiles.

# %%
DF.describe().year[3]
# Out:
# <ipython-input-37-883693519a82>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   DF.describe().year[3]
# np.float64(1998.0)

# %%
DF.describe()
# Out:
#               year     life_exp    hdi_index  co2_consump            gdp  \
# count  3675.000000  3675.000000  3563.000000  3671.000000    3633.000000
# mean   2008.000000    69.849306     0.674864     4.712731   11966.053675
# std       6.056125     8.886563     0.164834     6.567435   17105.787953
# min    1998.000000    32.500000     0.255000     0.015900     238.000000
# 25%    2003.000000    63.900000     0.537500     0.560500    1470.000000
# 50%    2008.000000    71.700000     0.699000     2.250000    4280.000000
# 75%    2013.000000    76.400000     0.805000     6.615000   13600.000000
# max    2018.000000    84.800000     0.956000    67.100000  105000.000000
#
#           services
# count  3675.000000
# mean     51.248705
# std      18.312501
# min       5.590000
# 25%      37.600000
# 50%      52.900000
# 75%      65.700000
# max      88.500000

# %% [markdown]
# 9. Accessing DataFrame Columns:
# Use DF['column_name'] to access a specific column.
# For multiple columns, use a list inside the brackets, e.g., DF[['column1', 'column2']].

# %%
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
DF['hdi_index']
# Out:
# 0       0.344
# 1       0.348
# 2       0.350
# 3       0.353
# 4       0.384
#         ...
# 3670    0.547
# 3671    0.553
# 3672    0.558
# 3673    0.563
# 3674    0.569
# Name: hdi_index, Length: 3675, dtype: float64

# %%
DF[['continent','life_exp','hdi_index']]
# Out:
#      continent  life_exp  hdi_index
# 0         Asia      53.3      0.344
# 1         Asia      54.7      0.348
# 2         Asia      54.7      0.350
# 3         Asia      54.8      0.353
# 4         Asia      55.5      0.384
# ...        ...       ...        ...
# 3670    Africa      58.0      0.547
# 3671    Africa      58.6      0.553
# 3672    Africa      59.2      0.558
# 3673    Africa      59.9      0.563
# 3674    Africa      60.6      0.569
#
# [3675 rows x 3 columns]

# %%
DF['continent']
# Out:
# 0         Asia
# 1         Asia
# 2         Asia
# 3         Asia
# 4         Asia
#          ...
# 3670    Africa
# 3671    Africa
# 3672    Africa
# 3673    Africa
# 3674    Africa
# Name: continent, Length: 3675, dtype: object

# %%
#accesing single column
DF['gdp']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4        333.0
#          ...
# 3670    1440.0
# 3671    1450.0
# 3672    1430.0
# 3673    1480.0
# 3674    1510.0
# Name: gdp, Length: 3675, dtype: float64

# %%
#accesing multiples column
DF[['gdp','services']]
# Out:
#          gdp  services
# 0        NaN      24.4
# 1        NaN      24.6
# 2        NaN      24.7
# 3        NaN      24.7
# 4      333.0      25.6
# ...      ...       ...
# 3670  1440.0      25.4
# 3671  1450.0      25.7
# 3672  1430.0      26.1
# 3673  1480.0      26.6
# 3674  1510.0      27.2
#
# [3675 rows x 2 columns]

# %% [markdown]
# **Note:** we can also print the list of columns headers(title) by using the below command. It is beacuse column is an attribute.

# %%
DF.columns
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='object')

# %%
# DATAFRAMES can be like your DICTIONARIES, because they also consist of your KEYS and VALUES.

# %% [markdown]
# Dataframes can be used as keys using **df.keys()**. It serves the same purpose like dictinary data *structure*.

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1998, ..., 0.0522, nan, 24.4],
#        ['Afghanistan', 'Asia', 1999, ..., 0.0402, nan, 24.6],
#        ['Afghanistan', 'Asia', 2000, ..., 0.037, nan, 24.7],
#        ...,
#        ['Zimbabwe', 'Africa', 2016, ..., 0.771, 1430.0, 26.1],
#        ['Zimbabwe', 'Africa', 2017, ..., 0.845, 1480.0, 26.6],
#        ['Zimbabwe', 'Africa', 2018, ..., 0.85, 1510.0, 27.2]],
#       dtype=object)

# %%
df.keys()
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='object')

# %% [markdown]
# Additionally, we can perform other sets of *operations* by combining the different methods

# %%
#print the first five values form column named country
DF['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
#print the first five values form columns named country and life_exp
DF[['country','life_exp']].head()
# Out:
#        country  life_exp
# 0  Afghanistan      53.3
# 1  Afghanistan      54.7
# 2  Afghanistan      54.7
# 3  Afghanistan      54.8
# 4  Afghanistan      55.5

# %% [markdown]
# 10. Dropping a Column (drop):
#
#
# *   To remove a column, use DF.drop('column_name', axis=1).

# %%
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
DF.columns
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='object')

# %%
# DF.drop('continent')

# %%
DF.drop('continent',axis=1)
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
# 1     Afghanistan  1999      54.7      0.348       0.0402     NaN      24.6
# 2     Afghanistan  2000      54.7      0.350       0.0370     NaN      24.7
# 3     Afghanistan  2001      54.8      0.353       0.0376     NaN      24.7
# 4     Afghanistan  2002      55.5      0.384       0.0471   333.0      25.6
# ...           ...   ...       ...        ...          ...     ...       ...
# 3670     Zimbabwe  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671     Zimbabwe  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672     Zimbabwe  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673     Zimbabwe  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674     Zimbabwe  2018      60.6      0.569       0.8500  1510.0      27.2
#
# [3675 rows x 7 columns]

# %%
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
 DF.drop('year', axis=1)
# Out:
#           country continent  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia      55.5      0.384       0.0471   333.0
# ...           ...       ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# 2         24.7
# 3         24.7
# 4         25.6
# ...        ...
# ...

# %% [markdown]
# *   To reflect this change in the original DataFrame, use inplace=True or reassign it like DF = DF.drop('column_name', axis=1).

# %%
df.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-62b65cbffb38> in <cell line: 0>()
# ----> 1 df.drop()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4778                 axes["columns"] = columns
#    4779         else:
# -> 4780             raise ValueError(
#    4781                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4782             )
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %%
# DF = DF.drop('year', axis=1)

DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
DF.drop(['life_exp','hdi_index'],axis=1)
# Out:
#           country continent  year  co2_consump     gdp  services
# 0     Afghanistan      Asia  1998       0.0522     NaN      24.4
# 1     Afghanistan      Asia  1999       0.0402     NaN      24.6
# 2     Afghanistan      Asia  2000       0.0370     NaN      24.7
# 3     Afghanistan      Asia  2001       0.0376     NaN      24.7
# 4     Afghanistan      Asia  2002       0.0471   333.0      25.6
# ...           ...       ...   ...          ...     ...       ...
# 3670     Zimbabwe    Africa  2014       0.8810  1440.0      25.4
# 3671     Zimbabwe    Africa  2015       0.8810  1450.0      25.7
# 3672     Zimbabwe    Africa  2016       0.7710  1430.0      26.1
# 3673     Zimbabwe    Africa  2017       0.8450  1480.0      26.6
# 3674     Zimbabwe    Africa  2018       0.8500  1510.0      27.2
#
# [3675 rows x 6 columns]

# %% [markdown]
# 11. Resetting the DataFrame:
# To revert to the original DataFrame, reread the CSV file.

# %%
DF = pd.read_csv(csv_url)
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1998, ..., 0.0522, nan, 24.4],
#        ['Afghanistan', 'Asia', 1999, ..., 0.0402, nan, 24.6],
#        ['Afghanistan', 'Asia', 2000, ..., 0.037, nan, 24.7],
#        ...,
#        ['Zimbabwe', 'Africa', 2016, ..., 0.771, 1430.0, 26.1],
#        ['Zimbabwe', 'Africa', 2017, ..., 0.845, 1480.0, 26.6],
#        ['Zimbabwe', 'Africa', 2018, ..., 0.85, 1510.0, 27.2]],
#       dtype=object)

# %%
#dropna, which drops or removes rows with 1 or more null value.
df.dropna()
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# 5     Afghanistan      Asia  2003      56.5      0.393       0.0509   346.0
# 6     Afghanistan      Asia  2004      57.1      0.409       0.0368   336.0
# 7     Afghanistan      Asia  2005      57.6      0.418       0.0515   360.0
# 8     Afghanistan      Asia  2006      58.0      0.429       0.0622   368.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 4         25.6
# 5         25.9
# ...

# %% [markdown]
# ### Series
#  In pandas, Series is equivalent to vectors in NumPy, representing basic data structures alongside Data Frames, tailored for seamless integration within the broader context of pandas' data-handling functionalities.
# * Usage
#     * Accessing Columns: To access a column, use the syntax df['column_name']. For instance, c = df['life_expectancy'] stores the 'life_expectancy' column in c.
#     * Series as Output: Both rows and columns, when accessed individually, are represented as a Series.

# %%
DF['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: object

# %%
pd.Series(DF['country'])
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: object

# %%
# Accessing a single column
DF['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: object

# %% [markdown]
# #### Series Operations

# %% [markdown]
# Pandas Series supports various functions like **sum(), min(), max(), count()**, etc., for aggregation.
# Performing these functions on 'life_exp' series
#  * sum()

# %%
3675.000000*69.849306
# Out:
# 256696.19955

# %%
DF.describe()
# Out:
#               year     life_exp    hdi_index  co2_consump            gdp  \
# count  3675.000000  3675.000000  3563.000000  3671.000000    3633.000000
# mean   2008.000000    69.849306     0.674864     4.712731   11966.053675
# std       6.056125     8.886563     0.164834     6.567435   17105.787953
# min    1998.000000    32.500000     0.255000     0.015900     238.000000
# 25%    2003.000000    63.900000     0.537500     0.560500    1470.000000
# 50%    2008.000000    71.700000     0.699000     2.250000    4280.000000
# 75%    2013.000000    76.400000     0.805000     6.615000   13600.000000
# max    2018.000000    84.800000     0.956000    67.100000  105000.000000
#
#           services
# count  3675.000000
# mean     51.248705
# std      18.312501
# min       5.590000
# 25%      37.600000
# 50%      52.900000
# 75%      65.700000
# max      88.500000

# %%
 # calculates the total sum of the 'life_expec' Series
 DF['life_exp'].sum()
# Out:
# np.float64(256696.2)

# %% [markdown]
# * min()

# %%
DF['life_exp'].min()
# Out:
# 32.5

# %% [markdown]
# * max()

# %%
DF['life_exp'].max()
# Out:
# 84.8

# %% [markdown]
# * count()

# %%
DF['life_exp'].count()
# Out:
# np.int64(3675)

# %% [markdown]
# * mean()

# %%
DF['life_exp'].mean()
# Out:
# np.float64(69.84930612244898)

# %%
DF['year'].mean()
# Out:
# np.float64(2008.0)

# %% [markdown]
# ## Understanding loc and iloc

# %% [markdown]
# loc
#   * Used for accessing rows by labels/indexes.
# Works with the row labels, which are the indexes by default in pandas.
#
# * If rows are deleted, loc continues to reference the original labels unless they are explicitly updated.
#
# Let's explore the commands:

# %%
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
DF.iloc[2,4]
# Out:
# np.float64(0.35)

# %%
DF.loc[2,"continent"]
# Out:
# 'Asia'

# %%
# Accessing a single row
DF.loc[3]
# Out:
# country        Afghanistan
# continent             Asia
# year                  2001
# life_exp              54.8
# hdi_index            0.353
# co2_consump         0.0376
# gdp                    NaN
# services              24.7
# Name: 3, dtype: object

# %%
# Accessing multiple rows
DF.loc[[1, 10, 100]]
# Out:
#          country      continent  year  life_exp  hdi_index  co2_consump  \
# 1    Afghanistan           Asia  1999      54.7      0.348       0.0402
# 10   Afghanistan           Asia  2008      59.2      0.447       0.1520
# 100    Argentina  South America  2014      76.5      0.836       4.5600
#
#          gdp  services
# 1        NaN      24.6
# 10     415.0      28.2
# 100  13600.0      75.3

# %%
# Slicing with loc
DF.loc[1:5]
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 5  Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
#
#    services
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6
# 5      25.9

# %%
DF.loc[3:34,["year","co2_consump"]]
# Out:
#     year  co2_consump
# 3   2001       0.0376
# 4   2002       0.0471
# 5   2003       0.0509
# 6   2004       0.0368
# 7   2005       0.0515
# 8   2006       0.0622
# 9   2007       0.0838
# 10  2008       0.1520
# 11  2009       0.2380
# 12  2010       0.2900
# 13  2011       0.4060
# 14  2012       0.3450
# 15  2013       0.2800
# 16  2014       0.2530
# 17  2015       0.2620
# 18  2016       0.2450
# 19  2017       0.2470
# 20  2018       0.2540
# 21  1998       0.5630
# 22  1999       0.9560
# 23  2000       0.9660
# 24  2001       1.0300
# 25  2002       1.2000
# 26  2003       1.3800
# 27  2004       1.3400
# 28  2005       1.3800
# 29  2006       1.2700
# 30  2007       1.2900
# 31  2008       1.4600
# 32  2009       1.4700
# 33  2010       1.5600
# 34  2011       1.7900

# %% [markdown]
# What is Masking?
#
# In Pandas, masking refers to applying an operation to each individual value in a DataFrame column, resulting in a series of Boolean values.

# %%
DF[DF['year']>2004]
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 7     Afghanistan      Asia  2005      57.6      0.418       0.0515   360.0
# 8     Afghanistan      Asia  2006      58.0      0.429       0.0622   368.0
# 9     Afghanistan      Asia  2007      58.5      0.447       0.0838   409.0
# 10    Afghanistan      Asia  2008      59.2      0.447       0.1520   415.0
# 11    Afghanistan      Asia  2009      59.9      0.460       0.2380   492.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 7         26.5
# 8         26.9
# ...

# %% [markdown]
# Using .loc with a Mask:

# %%
# DATAFRAME[CONDITION--> Boolean]

# Only the values that are true will be returned..

# %%
# masking -> wherever life_exp > 60 will retain
DF[DF.life_exp>60]
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 12    Afghanistan      Asia  2010      60.5      0.472        0.290   547.0
# 13    Afghanistan      Asia  2011      61.0      0.477        0.406   533.0
# 14    Afghanistan      Asia  2012      61.4      0.489        0.345   580.0
# 15    Afghanistan      Asia  2013      61.9      0.496        0.280   592.0
# 16    Afghanistan      Asia  2014      61.9      0.500        0.253   588.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3650       Zambia    Africa  2015      60.8      0.569        0.271  1340.0
# 3651       Zambia    Africa  2016      61.4      0.571        0.296  1350.0
# 3652       Zambia    Africa  2017      61.9      0.578        0.304  1350.0
# 3653       Zambia    Africa  2018      62.5      0.582        0.302  1370.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 12        30.7
# 13        31.7
# ...

# %%
# masking -> wherever life_exp > 60 will retain
DF.loc[DF.life_exp>60]
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 12    Afghanistan      Asia  2010      60.5      0.472        0.290   547.0
# 13    Afghanistan      Asia  2011      61.0      0.477        0.406   533.0
# 14    Afghanistan      Asia  2012      61.4      0.489        0.345   580.0
# 15    Afghanistan      Asia  2013      61.9      0.496        0.280   592.0
# 16    Afghanistan      Asia  2014      61.9      0.500        0.253   588.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3650       Zambia    Africa  2015      60.8      0.569        0.271  1340.0
# 3651       Zambia    Africa  2016      61.4      0.571        0.296  1350.0
# 3652       Zambia    Africa  2017      61.9      0.578        0.304  1350.0
# 3653       Zambia    Africa  2018      62.5      0.582        0.302  1370.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 12        30.7
# 13        31.7
# ...

# %%
# Accessing rows and columns together
DF.loc[1:5, ['continent', 'country']]
# Out:
#   continent      country
# 1      Asia  Afghanistan
# 2      Asia  Afghanistan
# 3      Asia  Afghanistan
# 4      Asia  Afghanistan
# 5      Asia  Afghanistan

# %%
DF[DF['co2_consump'] > 0.3]
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 13    Afghanistan      Asia  2011      61.0      0.477        0.406   533.0
# 14    Afghanistan      Asia  2012      61.4      0.489        0.345   580.0
# 21        Albania    Europe  1998      74.8      0.655        0.563  1600.0
# 22        Albania    Europe  1999      75.1      0.665        0.956  1820.0
# 23        Albania    Europe  2000      75.4      0.671        0.966  1960.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 13        31.7
# 14        32.8
# ...

# %%
DF.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-cf649d6d3634> in <cell line: 0>()
# ----> 1 DF.drop()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4778                 axes["columns"] = columns
#    4779         else:
# -> 4780             raise ValueError(
#    4781                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4782             )
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %%
#Dropping a col here
DF.drop('year',axis=1,inplace=True)

# %%
# Deleting a row here
DF.drop(5, inplace=True, axis=0)

# %%
DF.head(10)
# Out:
#         country continent  life_exp  hdi_index  co2_consump    gdp  services
# 0   Afghanistan      Asia      53.3      0.344       0.0522    NaN      24.4
# 1   Afghanistan      Asia      54.7      0.348       0.0402    NaN      24.6
# 2   Afghanistan      Asia      54.7      0.350       0.0370    NaN      24.7
# 3   Afghanistan      Asia      54.8      0.353       0.0376    NaN      24.7
# 4   Afghanistan      Asia      55.5      0.384       0.0471  333.0      25.6
# 6   Afghanistan      Asia      57.1      0.409       0.0368  336.0      26.1
# 7   Afghanistan      Asia      57.6      0.418       0.0515  360.0      26.5
# 8   Afghanistan      Asia      58.0      0.429       0.0622  368.0      26.9
# 9   Afghanistan      Asia      58.5      0.447       0.0838  409.0      27.7
# 10  Afghanistan      Asia      59.2      0.447       0.1520  415.0      28.2

# %% [markdown]
#   iloc
#  * Used for accessing rows by their integer positions.
# Works with the positional indexes, i.e., the numerical position of rows.
#  * Reflects the current structure of the DataFrame, adjusting to deletions or changes in the order of rows.
#
# Let's explore the commands:

# %%
# Accessing a single row
DF.iloc[3]
# Out:
# country        Afghanistan
# continent             Asia
# life_exp              54.8
# hdi_index            0.353
# co2_consump         0.0376
# gdp                    NaN
# services              24.7
# Name: 3, dtype: object

# %%
# Accessing multiple rows
DF.iloc[[1, 10, 100]]
# Out:
#          country      continent  life_exp  hdi_index  co2_consump      gdp  \
# 1    Afghanistan           Asia      54.7      0.348       0.0402      NaN
# 11   Afghanistan           Asia      59.9      0.460       0.2380    492.0
# 101    Argentina  South America      76.5      0.840       4.6400  13800.0
#
#      services
# 1        24.6
# 11       29.5
# 101      76.1

# %%
# Slicing with iloc
DF.iloc[1:5]
# Out:
#        country continent  life_exp  hdi_index  co2_consump    gdp  services
# 1  Afghanistan      Asia      54.7      0.348       0.0402    NaN      24.6
# 2  Afghanistan      Asia      54.7      0.350       0.0370    NaN      24.7
# 3  Afghanistan      Asia      54.8      0.353       0.0376    NaN      24.7
# 4  Afghanistan      Asia      55.5      0.384       0.0471  333.0      25.6

# %%
# Accessing rows and columns together
DF.iloc[1:5, 0:3]
# Out:
#        country continent  life_exp
# 1  Afghanistan      Asia      54.7
# 2  Afghanistan      Asia      54.7
# 3  Afghanistan      Asia      54.8
# 4  Afghanistan      Asia      55.5

# %% [markdown]
# ## Basic Operations in Pandas

# %% [markdown]
# 1. Accessing Columns:
#  * To access a column in a DataFrame, use the syntax df['column_name'].
#  * This returns the specified column as a Series.

# %%
#extracts the 'life_expectancy' column from DF and stores it in c.
c = DF['life_exp']
# returned series is stored and printed via c variable
c
# Out:
# 0       53.3
# 1       54.7
# 2       54.7
# 3       54.8
# 4       55.5
#         ...
# 3670    58.0
# 3671    58.6
# 3672    59.2
# 3673    59.9
# 3674    60.6
# Name: life_exp, Length: 3674, dtype: float64

# %% [markdown]
# 2. Calculating Mean of a Column:
# * Use the mean() method on a Series to calculate its mean value.
# Example: DF.mean() computes the mean of the 'life_exp' Series.

# %%
DF.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-86b3940b9e7d> in <cell line: 0>()
# ----> 1 DF.mean()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %% [markdown]
# * To find the mean of a specific column, you can reference it by name:

# %%
DF['life_exp'].mean()
# Out:
# np.float64(69.85293957539467)

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# * Conditional Filtering:
#  * Apply conditions directly to DataFrame columns for filtering.

# %%
DF[(DF['life_exp']>30) & (df['life_exp']<40)]
# Out:
# <ipython-input-98-5cb0438efaba>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DF[(DF['life_exp']>30) & (df['life_exp']<40)]
#      country      continent  life_exp  hdi_index  co2_consump     gdp  \
# 1419   Haiti  North America      32.5      0.471        0.211  1290.0
#
#       services
# 1419      59.9

# %%
df[(df['life_exp']>30)&(df['life_exp']<40)]
# Out:
#      country      continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 1419   Haiti  North America  2010      32.5      0.471        0.211  1290.0
#
#       services
# 1419      59.9

# %%
#filters the DataFrame to only include rows where life expectancy is greater than 40.
DF[DF['life_exp'] > 40]
# Out:
#           country continent  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia      55.5      0.384       0.0471   333.0
# ...           ...       ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# 2         24.7
# 3         24.7
# 4         25.6
# ...        ...
# ...

# %% [markdown]
# * For multiple conditions, combine them using & (AND) and | (OR), with each condition enclosed in parentheses.

# %%
#filters for life expectancy between 30 and 40.
df[(df['life_exp'] > 30) & (df['life_exp'] <= 40)]
# Out:
#      country      continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 1419   Haiti  North America  2010      32.5      0.471        0.211  1290.0
#
#       services
# 1419      59.9

# %% [markdown]
# ###Grouping Data

# %%
DF.groupby('country')['life_exp'].min()
# Out:
# country
# Afghanistan    53.3
# Albania        74.8
# Algeria        70.2
# Angola         50.6
# Argentina      73.7
#                ...
# Vanuatu        63.0
# Vietnam        71.7
# Yemen          62.5
# Zambia         45.2
# Zimbabwe       46.4
# Name: life_exp, Length: 175, dtype: float64

# %%
DF.columns
# Out:
# Index(['country', 'continent', 'life_exp', 'hdi_index', 'co2_consump', 'gdp',
#        'services'],
#       dtype='object')

# %%
DF = pd.read_csv(csv_url)

# %% [markdown]
# * GroupBy Functionality:
#   * The groupby() method groups DataFrame rows based on a column's values.
#   * After grouping, you can apply aggregation functions like mean(), sum(), etc.

# %%
#Example:  calculates the average life expectancy for each year.
DF.groupby('year')['life_exp'].mean()
# Out:
# year
# 1998    66.912000
# 1999    67.125714
# 2000    67.410286
# 2001    67.676000
# 2002    67.873714
# 2003    68.094286
# 2004    68.371429
# 2005    68.735429
# 2006    69.122857
# 2007    69.516571
# 2008    69.850286
# 2009    70.217714
# 2010    70.473143
# 2011    70.967429
# 2012    71.312571
# 2013    71.607429
# 2014    71.804000
# 2015    72.045143
# 2016    72.324000
# 2017    72.584571
# 2018    72.810857
# Name: life_exp, dtype: float64

# %% [markdown]
#   * Counting Unique Values:
# nunique() method counts the number of unique values in a column.

# %%
#counts the number of unique countries in each continent.
DF.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa           51
# Asia             47
# Europe           39
# North America    19
# Oceania           8
# South America    11
# Name: country, dtype: int64

# %%
#counts the number of unique countries in each continent.
DF.groupby('year')[['life_exp','gdp']].count()
# Out:
#       life_exp  gdp
# year
# 1998       175  167
# 1999       175  168
# 2000       175  171
# 2001       175  172
# 2002       175  173
# 2003       175  173
# 2004       175  173
# 2005       175  173
# 2006       175  173
# 2007       175  173
# 2008       175  174
# 2009       175  174
# 2010       175  174
# 2011       175  174
# 2012       175  174
# 2013       175  175
# 2014       175  175
# 2015       175  175
# 2016       175  174
# 2017       175  174
# 2018       175  174

# %% [markdown]
# The above output represents the count of unique countries within each continent group.

# %% [markdown]
# * Multi-Level Grouping:
#  * Group by multiple columns by passing a list of column names to groupby().
#  * This creates hierarchical indices based on the specified columns.

# %%
DF.groupby(['continent','year'])[['life_exp','gdp']].mean()
# Out:
#                      life_exp          gdp
# continent     year
# Africa        1998  56.111765  1549.021739
#               1999  56.250980  1664.212766
#               2000  56.401961  1673.479167
#               2001  56.658824  1723.857143
#               2002  56.894118  1762.265306
# ...                       ...          ...
# South America 2014  75.300000  8512.727273
#               2015  75.445455  8503.636364
#               2016  75.500000  8444.545455
#               2017  75.654545  8537.272727
#               2018  75.827273  8611.818182
#
# [126 rows x 2 columns]

# %%
#groups the data first by 'continent' and then by 'year', calculating the mean for each group.
DF.groupby(['continent', 'year']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
13 DECEMBER'2023'
# Out:
#   File "<ipython-input-114-766c863d59e5>", line 1
#     13 DECEMBER'2023'
#        ^
# SyntaxError: invalid syntax

# %%
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
#Other syntax to aggregate in groupby
DF.groupby(['']).agg({})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-283084a2b921> in <cell line: 0>()
#       1 #Other syntax to aggregate in groupby
# ----> 2 DF.groupby(['']).agg({})
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
# ...

# %%
DF
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
DF.groupby('continent').max()['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-1e46db412ce9> in <cell line: 0>()
# ----> 1 DF.groupby('continent').max()['']
#
# ...

# %%
DF.groupby(["continent","year"]).agg({'life_exp':'mean','co2_consump':'max'})
# Out:
#                      life_exp  co2_consump
# continent     year
# Africa        1998  56.111765         8.70
#               1999  56.250980         8.46
#               2000  56.401961         8.74
#               2001  56.658824         8.78
#               2002  56.894118         9.65
# ...                       ...          ...
# South America 2014  75.300000         4.56
#               2015  75.445455         4.64
#               2016  75.500000         4.62
#               2017  75.654545         4.55
#               2018  75.827273         4.59
#
# [126 rows x 2 columns]

# %%
merged_df.agg({'status_x':['sum','count']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-7e8f4bdf03cc> in <cell line: 0>()
# ----> 1 merged_df.agg({'status_x':['sum','count']})
#
# NameError: name 'merged_df' is not defined

# %% [markdown]
# ### Sorting Data
# * Basic Sorting: df.sort_values('life_exp') sorts the DataFrame based on the 'life expectancy' column in ascending order.

# %%
df.sort_values('co2_consump',ascending=False).sort_values("country",ascending=True)
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 5     Afghanistan      Asia  2003      56.5      0.393       0.0509   346.0
# 14    Afghanistan      Asia  2012      61.4      0.489       0.3450   580.0
# 11    Afghanistan      Asia  2009      59.9      0.460       0.2380   492.0
# 10    Afghanistan      Asia  2008      59.2      0.447       0.1520   415.0
# 12    Afghanistan      Asia  2010      60.5      0.472       0.2900   547.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3667     Zimbabwe    Africa  2011      54.4      0.499       0.7370  1250.0
# 3664     Zimbabwe    Africa  2008      48.9      0.422       0.6240   850.0
# 3668     Zimbabwe    Africa  2012      56.0      0.525       0.5870  1430.0
# 3660     Zimbabwe    Africa  2004      46.4      0.411       0.7850  1210.0
#
#       services
# 5         25.9
# 14        32.8
# ...

# %%
df.sort_values(["co2_consump","gdp"],ascending=[False,True])
# Out:
#                country continent  year  life_exp  hdi_index  co2_consump  \
# 2691             Qatar      Asia  2001      71.5      0.817      67.1000
# 2692             Qatar      Asia  2002      71.5      0.822      63.6000
# 2696             Qatar      Asia  2006      72.1      0.835      61.8000
# 2693             Qatar      Asia  2003      71.7      0.830      60.6000
# 2695             Qatar      Asia  2005      72.3      0.838      58.6000
# ...                ...       ...   ...       ...        ...          ...
# 759   Congo, Dem. Rep.    Africa  2001      54.2      0.350       0.0159
# 3278       Timor-Leste      Asia  2000      65.5      0.484          NaN
# 3279       Timor-Leste      Asia  2001      65.8      0.492          NaN
# 3276       Timor-Leste      Asia  1998      63.8        NaN          NaN
# 3277       Timor-Leste      Asia  1999      58.5        NaN          NaN
#
#           gdp  services
# 2691  56900.0      59.3
# 2692  58500.0      58.5
# ...

# %%
df.sort_values('life_exp')
# Out:
#                        country      continent  year  life_exp  hdi_index  \
# 1419                     Haiti  North America  2010      32.5      0.471
# 1098                  Eswatini         Africa  2004      43.1      0.445
# 1099                  Eswatini         Africa  2005      43.3      0.456
# 630   Central African Republic         Africa  1998      43.8      0.320
# 631   Central African Republic         Africa  1999      43.8      0.323
# ...                        ...            ...   ...       ...        ...
# 1698                     Japan           Asia  2016      84.5      0.912
# 2917                 Singapore           Asia  2017      84.7      0.933
# 2918                 Singapore           Asia  2018      84.7      0.936
# 1699                     Japan           Asia  2017      84.7      0.915
# 1700                     Japan           Asia  2018      84.8      0.917
#
#       co2_consump      gdp  services
# 1419       0.2110   1290.0      59.9
# ...

# %% [markdown]
# * Changing Sort Order: Adding **ascending=False** sorts in descending order.

# %%
df.sort_values('life_exp',ascending=False)
# Out:
#                        country      continent  year  life_exp  hdi_index  \
# 1700                     Japan           Asia  2018      84.8      0.917
# 2918                 Singapore           Asia  2018      84.7      0.936
# 1699                     Japan           Asia  2017      84.7      0.915
# 2917                 Singapore           Asia  2017      84.7      0.933
# 1698                     Japan           Asia  2016      84.5      0.912
# ...                        ...            ...   ...       ...        ...
# 631   Central African Republic         Africa  1999      43.8      0.323
# 630   Central African Republic         Africa  1998      43.8      0.320
# 1099                  Eswatini         Africa  2005      43.3      0.456
# 1098                  Eswatini         Africa  2004      43.1      0.445
# 1419                     Haiti  North America  2010      32.5      0.471
#
#       co2_consump      gdp  services
# 1700       9.1400  36200.0      72.1
# ...

# %% [markdown]
# * Multi-Level Sorting: Sorting can be done on multiple columns.

# %%
DF.sort_values(by=['country', 'year'])
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
#sorts primarily by 'life expectancy' and then by 'year' within each 'life expectancy' group.

DF.sort_values(by=['country', 'year'],ascending=[True,False])
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 20    Afghanistan      Asia  2018      62.7      0.509        0.254   569.0
# 19    Afghanistan      Asia  2017      62.9      0.506        0.247   576.0
# 18    Afghanistan      Asia  2016      62.0      0.502        0.245   575.0
# 17    Afghanistan      Asia  2015      61.9      0.500        0.262   578.0
# 16    Afghanistan      Asia  2014      61.9      0.500        0.253   588.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3658     Zimbabwe    Africa  2002      46.6      0.423        0.996  1560.0
# 3657     Zimbabwe    Africa  2001      47.0      0.431        1.050  1720.0
# 3656     Zimbabwe    Africa  2000      47.5      0.430        1.160  1700.0
# 3655     Zimbabwe    Africa  1999      48.5      0.437        1.330  1760.0
# 3654     Zimbabwe    Africa  1998      49.7      0.442        1.200  1780.0
#
#       services
# 20        38.4
# 19        38.0
# ...

# %% [markdown]
# * Sorting Behavior: If the primary sort column (like 'life expectancy') has unique values for each row, the secondary sort column (like 'year') may not influence the order.

# %%
# Sort the DataFrame first by 'Life_Exp' in ascending order,
# and then by 'Year' in ascending order for ties in 'Life_Exp'

DF.sort_values(by=['life_exp', 'year'])
# Out:
#                        country      continent  year  life_exp  hdi_index  \
# 1419                     Haiti  North America  2010      32.5      0.471
# 1098                  Eswatini         Africa  2004      43.1      0.445
# 1099                  Eswatini         Africa  2005      43.3      0.456
# 630   Central African Republic         Africa  1998      43.8      0.320
# 631   Central African Republic         Africa  1999      43.8      0.323
# ...                        ...            ...   ...       ...        ...
# 1698                     Japan           Asia  2016      84.5      0.912
# 1699                     Japan           Asia  2017      84.7      0.915
# 2917                 Singapore           Asia  2017      84.7      0.933
# 2918                 Singapore           Asia  2018      84.7      0.936
# 1700                     Japan           Asia  2018      84.8      0.917
#
#       co2_consump      gdp  services
# 1419       0.2110   1290.0      59.9
# ...

# %% [markdown]
# * Sorting with Different Orders: You can specify different sort orders for each column by passing a list to ascending.

# %%
#sorts the first column in ascending and the second in descending order.
DF.sort_values(by=['life_exp', 'year'], ascending=[True, False])
# Out:
#                        country      continent  year  life_exp  hdi_index  \
# 1419                     Haiti  North America  2010      32.5      0.471
# 1098                  Eswatini         Africa  2004      43.1      0.445
# 1099                  Eswatini         Africa  2005      43.3      0.456
# 632   Central African Republic         Africa  2000      43.8      0.325
# 631   Central African Republic         Africa  1999      43.8      0.323
# ...                        ...            ...   ...       ...        ...
# 1698                     Japan           Asia  2016      84.5      0.912
# 2918                 Singapore           Asia  2018      84.7      0.936
# 1699                     Japan           Asia  2017      84.7      0.915
# 2917                 Singapore           Asia  2017      84.7      0.933
# 1700                     Japan           Asia  2018      84.8      0.917
#
#       co2_consump      gdp  services
# 1419       0.2110   1290.0      59.9
# ...

# %% [markdown]
# ### String Operations

# %%
DF['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: object

# %%
DF['country']>'AAA'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3670    True
# 3671    True
# 3672    True
# 3673    True
# 3674    True
# Name: country, Length: 3675, dtype: bool

# %% [markdown]
# * String Comparison:
#  * Pandas supports string comparison operations, useful for filtering.

# %%
DF[DF['co2_consump']>0.3]
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 13    Afghanistan      Asia  2011      61.0      0.477        0.406   533.0
# 14    Afghanistan      Asia  2012      61.4      0.489        0.345   580.0
# 21        Albania    Europe  1998      74.8      0.655        0.563  1600.0
# 22        Albania    Europe  1999      75.1      0.665        0.956  1820.0
# 23        Albania    Europe  2000      75.4      0.671        0.966  1960.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 13        31.7
# 14        32.8
# ...

# %%
#filters the DataFrame for countries alphabetically before 'Nigeria'.
DF[DF['country'] < 'Nigeria']
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# ...           ...       ...   ...       ...        ...          ...    ...
# 2410        Niger    Africa  2014      60.4      0.365       0.1070  482.0
# 2411        Niger    Africa  2015      60.6      0.372       0.1010  484.0
# 2412        Niger    Africa  2016      61.1      0.378       0.0967  493.0
# 2413        Niger    Africa  2017      61.5      0.386       0.1030  498.0
# 2414        Niger    Africa  2018      62.0      0.391       0.1030  514.0
#
#       services
# 0         24.4
# 1         24.6
# 2         24.7
# ...

# %% [markdown]
# ### Resetting Index
#
#   * After operations like filtering or grouping, the DataFrame's index may need to be reset for consistency.
#   * Use DF.reset_index() to reset the index of the DataFrame.
#   * This method is also useful when indices become non-sequential after row deletions.

# %%
xyz=DF.drop(2,axis=0)

# %%
xyz.reset_index(drop=True)
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 3     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# 4     Afghanistan      Asia  2003      56.5      0.393       0.0509   346.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3669     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3670     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3671     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3672     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3673     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
DF.set_index('country').reset_index()
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
#Reset the index
DF.reset_index()
# Out:
#       index      country continent  year  life_exp  hdi_index  co2_consump  \
# 0         0  Afghanistan      Asia  1998      53.3      0.344       0.0522
# 1         1  Afghanistan      Asia  1999      54.7      0.348       0.0402
# 2         2  Afghanistan      Asia  2000      54.7      0.350       0.0370
# 3         3  Afghanistan      Asia  2001      54.8      0.353       0.0376
# 4         4  Afghanistan      Asia  2002      55.5      0.384       0.0471
# ...     ...          ...       ...   ...       ...        ...          ...
# 3670   3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810
# 3671   3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810
# 3672   3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710
# 3673   3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450
# 3674   3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500
#
#          gdp  services
# 0        NaN      24.4
# ...

# %% [markdown]
# ##Restructuring Data with Melt
# Using **pd.melt**:
#
#  * Method Application: Showed how to use pd.melt to restructure the DataFrame. This process involved merging multiple 'day' columns into a single 'day' column and creating a corresponding 'temp' column for temperatures.
#
#  * Resulting Format: The outcome was a more streamlined DataFrame with consolidated day and temperature data.
#
# Understanding **pd.melt** Parameters:
#    * **id_vars:** Explained the use of id_vars to specify columns that should remain unchanged during the melt process.
#    * **var_name and value_name**: Clarified the roles of var_name (to store the name of the melted columns) and value_name (to store the corresponding values).

# %%
import pandas as pd
# Use the correct raw URL for the CSV file on GitHub
csv_url = 'https://raw.githubusercontent.com/yesdhruv/csv_files/master/weather.csv'


weather = pd.read_csv(csv_url)
# Display the DataFrame
weather
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
weather.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
# Perform the melt operation
weather_melt = pd.melt(weather,
                       id_vars=['MinTemp', 'MaxTemp', 'Rainfall'],  # Include actual columns in your DataFrame
                       var_name='day',
                       value_name='temp')

# %%
weather_melt[weather_melt['MinTemp']==8.0]
# Out:
#       MinTemp  MaxTemp  Rainfall            day    temp
# 0         8.0     24.3       0.0    Evaporation     3.4
# 366       8.0     24.3       0.0       Sunshine     6.3
# 732       8.0     24.3       0.0    WindGustDir      NW
# 1098      8.0     24.3       0.0  WindGustSpeed    30.0
# 1464      8.0     24.3       0.0     WindDir9am      SW
# 1830      8.0     24.3       0.0     WindDir3pm      NW
# 2196      8.0     24.3       0.0   WindSpeed9am     6.0
# 2562      8.0     24.3       0.0   WindSpeed3pm      20
# 2928      8.0     24.3       0.0    Humidity9am      68
# 3294      8.0     24.3       0.0    Humidity3pm      29
# 3660      8.0     24.3       0.0    Pressure9am  1019.7
# 4026      8.0     24.3       0.0    Pressure3pm  1015.0
# 4392      8.0     24.3       0.0       Cloud9am       7
# 4758      8.0     24.3       0.0       Cloud3pm       7
# 5124      8.0     24.3       0.0        Temp9am    14.4
# 5490      8.0     24.3       0.0        Temp3pm    23.6
# ...

# %%
weather_melt
# Out:
#       MinTemp  MaxTemp  Rainfall           day temp
# 0         8.0     24.3       0.0   Evaporation  3.4
# 1        14.0     26.9       3.6   Evaporation  4.4
# 2        13.7     23.4       3.6   Evaporation  5.8
# 3        13.3     15.5      39.8   Evaporation  7.2
# 4         7.6     16.1       2.8   Evaporation  5.6
# ...       ...      ...       ...           ...  ...
# 6949      9.0     30.7       0.0  RainTomorrow   No
# 6950      7.1     28.4       0.0  RainTomorrow   No
# 6951     12.5     19.9       0.0  RainTomorrow   No
# 6952     12.5     26.9       0.0  RainTomorrow   No
# 6953     12.3     30.2       0.0  RainTomorrow   No
#
# [6954 rows x 5 columns]

# %%
print(weather_melt.shape)
# Display the first few rows of the melted DataFrame
weather_melt.head()
# Out:
# (6954, 5)
#    MinTemp  MaxTemp  Rainfall          day temp
# 0      8.0     24.3       0.0  Evaporation  3.4
# 1     14.0     26.9       3.6  Evaporation  4.4
# 2     13.7     23.4       3.6  Evaporation  5.8
# 3     13.3     15.5      39.8  Evaporation  7.2
# 4      7.6     16.1       2.8  Evaporation  5.6

# %%
weather_melt.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'day', 'temp'], dtype='object')

# %%
weather_melt.groupby(['day']).agg({'Rainfall':'first'})
# Out:
#                Rainfall
# day
# Cloud3pm            0.0
# Cloud9am            0.0
# Evaporation         0.0
# Humidity3pm         0.0
# Humidity9am         0.0
# Pressure3pm         0.0
# Pressure9am         0.0
# RISK_MM             0.0
# RainToday           0.0
# RainTomorrow        0.0
# Sunshine            0.0
# Temp3pm             0.0
# Temp9am             0.0
# WindDir3pm          0.0
# WindDir9am          0.0
# WindGustDir         0.0
# WindGustSpeed       0.0
# WindSpeed3pm        0.0
# WindSpeed9am        0.0

# %%
weather_melt
# Out:
#       MinTemp  MaxTemp  Rainfall           day temp
# 0         8.0     24.3       0.0   Evaporation  3.4
# 1        14.0     26.9       3.6   Evaporation  4.4
# 2        13.7     23.4       3.6   Evaporation  5.8
# 3        13.3     15.5      39.8   Evaporation  7.2
# 4         7.6     16.1       2.8   Evaporation  5.6
# ...       ...      ...       ...           ...  ...
# 6949      9.0     30.7       0.0  RainTomorrow   No
# 6950      7.1     28.4       0.0  RainTomorrow   No
# 6951     12.5     19.9       0.0  RainTomorrow   No
# 6952     12.5     26.9       0.0  RainTomorrow   No
# 6953     12.3     30.2       0.0  RainTomorrow   No
#
# [6954 rows x 5 columns]

# %%
# Pivot the melted DataFrame back to its original format
weather_pivot = weather_melt.pivot_table(index=['Rainfall', 'MinTemp', 'MaxTemp'],
                                         columns='day',
                                         values='temp',
                                         aggfunc='first')



# Display the pivoted DataFrame
weather_pivot.head()
# Out:
# day                      Cloud3pm Cloud9am Evaporation Humidity3pm  \
# Rainfall MinTemp MaxTemp
# 0.0      -5.3    13.1           6        6         2.2          47
#          -3.7    14.4           0        0         2.6          28
#                  14.7           0        0         3.4          25
#          -3.5    11.2           5        1         1.6          48
#          -3.4    12.5           7        6         3.0          30
#
# day                      Humidity9am Pressure3pm Pressure9am RISK_MM  \
# Rainfall MinTemp MaxTemp
# 0.0      -5.3    13.1             94      1025.6      1029.6     0.0
#          -3.7    14.4             64      1028.0      1031.0     0.0
#                  14.7             53      1020.9      1025.8     0.0
#          -3.5    11.2             76      1031.1      1033.5     0.0
#          -3.4    12.5             89      1021.8      1025.2     0.0
#
# day                      RainToday RainTomorrow Sunshine Temp3pm Temp9am  \
# ...

# %%
weather_pivot.reset_index()
# Out:
# day  Rainfall  MinTemp  MaxTemp Cloud3pm Cloud9am Evaporation Humidity3pm  \
# 0         0.0     -5.3     13.1        6        6         2.2          47
# 1         0.0     -3.7     14.4        0        0         2.6          28
# 2         0.0     -3.7     14.7        0        0         3.4          25
# 3         0.0     -3.5     11.2        5        1         1.6          48
# 4         0.0     -3.4     12.5        7        6         3.0          30
# ..        ...      ...      ...      ...      ...         ...         ...
# 360      19.2      2.3     11.6        3        7         1.8          56
# 361      19.8     12.6     20.2        4        5         2.6          50
# 362      22.6     15.1     20.4        8        8         2.4          90
# 363      25.8     12.8     18.5        8        8         2.8          79
# 364      39.8     13.3     15.5        7        2         7.2          56
#
# day Humidity9am Pressure3pm Pressure9am  ... RainTomorrow Sunshine Temp3pm  \
# ...

# %%
# Reset the index to make it look like the original DataFrame
weather_pivot.reset_index(inplace=True)

weather_pivot.head()
# Out:
# day  Rainfall  MinTemp  MaxTemp Cloud3pm Cloud9am Evaporation Humidity3pm  \
# 0         0.0     -5.3     13.1        6        6         2.2          47
# 1         0.0     -3.7     14.4        0        0         2.6          28
# 2         0.0     -3.7     14.7        0        0         3.4          25
# 3         0.0     -3.5     11.2        5        1         1.6          48
# 4         0.0     -3.4     12.5        7        6         3.0          30
#
# day Humidity9am Pressure3pm Pressure9am  ... RainTomorrow Sunshine Temp3pm  \
# 0            94      1025.6      1029.6  ...           No      7.9    12.2
# 1            64      1028.0      1031.0  ...           No     10.4    14.0
# 2            53      1020.9      1025.8  ...           No     10.9    13.4
# 3            76      1031.1      1033.5  ...           No      7.7    10.1
# 4            89      1021.8      1025.2  ...           No      6.8    11.2
#
# ...

# %%
weather_melt
# Out:
#       MinTemp  MaxTemp  Rainfall           day temp
# 0         8.0     24.3       0.0   Evaporation  3.4
# 1        14.0     26.9       3.6   Evaporation  4.4
# 2        13.7     23.4       3.6   Evaporation  5.8
# 3        13.3     15.5      39.8   Evaporation  7.2
# 4         7.6     16.1       2.8   Evaporation  5.6
# ...       ...      ...       ...           ...  ...
# 6949      9.0     30.7       0.0  RainTomorrow   No
# 6950      7.1     28.4       0.0  RainTomorrow   No
# 6951     12.5     19.9       0.0  RainTomorrow   No
# 6952     12.5     26.9       0.0  RainTomorrow   No
# 6953     12.3     30.2       0.0  RainTomorrow   No
#
# [6954 rows x 5 columns]

# %%
weather_melt.pivot_table(index=['Rainfall', 'MinTemp', 'MaxTemp'],
                                         columns='day',
                                         values='temp',
                                         aggfunc='first',
                                         dropna=False).reset_index()
# Out:
# day      Rainfall  MinTemp  MaxTemp Cloud3pm Cloud9am Evaporation Humidity3pm  \
# 0             0.0     -5.3      7.6      NaN      NaN         NaN         NaN
# 1             0.0     -5.3      8.4      NaN      NaN         NaN         NaN
# 2             0.0     -5.3      8.7      NaN      NaN         NaN         NaN
# 3             0.0     -5.3      8.8      NaN      NaN         NaN         NaN
# 4             0.0     -5.3      9.3      NaN      NaN         NaN         NaN
# ...           ...      ...      ...      ...      ...         ...         ...
# 1582015      39.8     20.9     34.9      NaN      NaN         NaN         NaN
# 1582016      39.8     20.9     35.0      NaN      NaN         NaN         NaN
# 1582017      39.8     20.9     35.2      NaN      NaN         NaN         NaN
# 1582018      39.8     20.9     35.7      NaN      NaN         NaN         NaN
# 1582019      39.8     20.9     35.8      NaN      NaN         NaN         NaN
#
# ...

# %%
weather_melt.pivot_table(index=['Rainfall', 'MinTemp', 'MaxTemp'],
                                         columns='day',
                                         values='temp',
                                         aggfunc='first',
                                         dropna=True).reset_index()
# Out:
# day  Rainfall  MinTemp  MaxTemp Cloud3pm Cloud9am Evaporation Humidity3pm  \
# 0         0.0     -5.3     13.1        6        6         2.2          47
# 1         0.0     -3.7     14.4        0        0         2.6          28
# 2         0.0     -3.7     14.7        0        0         3.4          25
# 3         0.0     -3.5     11.2        5        1         1.6          48
# 4         0.0     -3.4     12.5        7        6         3.0          30
# ..        ...      ...      ...      ...      ...         ...         ...
# 360      19.2      2.3     11.6        3        7         1.8          56
# 361      19.8     12.6     20.2        4        5         2.6          50
# 362      22.6     15.1     20.4        8        8         2.4          90
# 363      25.8     12.8     18.5        8        8         2.8          79
# 364      39.8     13.3     15.5        7        2         7.2          56
#
# day Humidity9am Pressure3pm Pressure9am  ... RainTomorrow Sunshine Temp3pm  \
# ...

# %% [markdown]
# ##Applying Custom Functions in Pandas

# %%
df[['hdi_index','life_exp']].apply(lambda x:x+2)
# Out:
#       hdi_index  life_exp
# 0         2.344      55.3
# 1         2.348      56.7
# 2         2.350      56.7
# 3         2.353      56.8
# 4         2.384      57.5
# ...         ...       ...
# 3670      2.547      60.0
# 3671      2.553      60.6
# 3672      2.558      61.2
# 3673      2.563      61.9
# 3674      2.569      62.6
#
# [3675 rows x 2 columns]

# %%
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %% [markdown]
# **.apply()**: This method is used to apply a function along the axis of a DataFrame or Series.

# %% [markdown]
# * Axis Specification in .apply():
#  * When Axis=0: The function collapses the rows and applies mean_func to each column separately. This results in the mean of each column being calculated.
#
#  * When Axis=1: The function collapses the columns and applies mean_func to each row. This results in the mean of the values in each row being calculated.

# %% [markdown]
# A custom function named **mean_func** is created to demonstrate the application of functions in Pandas. This function was designed to calculate the mean of a given set of values.
#
# The function takes an input x and returns the mean calculated as the sum of x divided by the length of x.

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.DataFrame([[1,2,3,4],[5,6,7,8]],columns=['A','B','C','D'])
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  5  6  7  8

# %%
pd.DataFrame({'A':[1,2,3,4,5],'B':[6,5,4,3,2]})
# Out:
#    A  B
# 0  1  6
# 1  2  5
# 2  3  4
# 3  4  3
# 4  5  2

# %%
import pandas as pd

def mean_func(x):
    """
    Calculate the mean of a given set of values.

    Parameters:
    - x: Input values for which the mean is calculated.

    Returns:
    - Mean value calculated as the sum of x divided by the length of x.
    """
    # Convert the values to numeric to handle mixed data types
    x_numeric = pd.to_numeric(x, errors='coerce')
    return x_numeric.sum() / len(x_numeric)

# Creating a sample DataFrame
data = {'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
        'Min_Temperature': [18, 20, 22, 19, 17],
        'Max_Temperature': [25, 28, 24, 26, 23]}
df = pd.DataFrame(data)
df
# Out:
#          Day  Min_Temperature  Max_Temperature
# 0     Monday               18               25
# 1    Tuesday               20               28
# 2  Wednesday               22               24
# 3   Thursday               19               26
# 4     Friday               17               23

# %%
43/3
# Out:
# 14.333333333333334

# %%
df.apply(mean_func,axis=1)
# Out:
# 0    14.333333
# 1    16.000000
# 2    15.333333
# 3    15.000000
# 4    13.333333
# dtype: float64

# %%
# Applying mean_func with axis=0 (Column-wise mean)
column_means = df.apply(mean_func, axis=0)


# Displaying the results
print("Column-wise Mean:")
print(column_means)
# Out:
# Column-wise Mean:
# Day                 0.0
# Min_Temperature    19.2
# Max_Temperature    25.2
# dtype: float64

# %%
# Applying mean_func with axis=1 (Row-wise mean)
row_means = df.apply(mean_func, axis=1)

print("\nRow-wise Mean:")
print(row_means)
# Out:
# Row-wise Mean:
# 0    14.333333
# 1    16.000000
# 2    15.333333
# 3    15.000000
# 4    13.333333
# dtype: float64

# %% [markdown]
# # Creating Series and DataFrames from Scratch

# %% [markdown]
# ## Creating a Series

# %% [markdown]
# * Series Constructor: pd.Series() is used to create a  Series. Remember, Series starts with an uppercase 'S', indicating it's a constructor.

# %%
# creates a Series with values 10, 20, and 30.
pd.Series([10, 20, 30,[40,50,40]])
# Out:
# 0              10
# 1              20
# 2              30
# 3    [40, 50, 40]
# dtype: object

# %% [markdown]
# ## Creating a DataFrame
# DataFrame Constructor: pd.DataFrame() is used for creating a DataFrame.

# %% [markdown]
# * Row-Based Creation: Passing a list of lists, where each inner list represents a row.

# %%
#creates a Pandas DataFrame with two columns, 'A' and 'B', and two rows.
pd.DataFrame([[10,20],[30,40]],columns=['A','B'])
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %% [markdown]
# * Column-Based Creation: Using a dictionary where keys are column names and values are lists of column data.

# %%
pd.DataFrame({'A': [10, 30], 'B': [20, 40]})
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %% [markdown]
# * Adding a Single Row: To add a single row, it must be wrapped in an additional list to represent a list of rows.

# %% [markdown]
#  Lets create two sample data frames for further operations

# %%
# Creating df1
df1 = pd.DataFrame({'A':[10, 30], 'B':[20, 40]})

df1
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
# Creating df2
df2 = pd.DataFrame({'A':[10, 30], 'C':[20, 40]})

df2
# Out:
#     A   C
# 0  10  20
# 1  30  40

# %%
df1.append(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-8ab0723181fb> in <cell line: 0>()
# ----> 1 df1.append(df2)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
pd.concat([df1, df2])
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %%
pd.concat([df1,df2],axis=0)

#df1.append(df2)
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   A   C
# 0  10  20  10  20
# 1  30  40  30  40

# %% [markdown]
# ## Concatenating a DataFrame
# * Vertical Concatenation
#  * Default Concatenation: Using pd.concat([df1, df2]) concatenates DataFrames vertically. Columns with the same name are aligned together.

# %%
pd.concat([df1, df2])
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %% [markdown]
# * Horizontal Concatenation
#  * Side-by-Side Concatenation: Setting axis=1 in pd.concat() concatenates DataFrames side by side.

# %%
 pd.concat([df1, df2], axis=1)
# Out:
#     A   B   A   C
# 0  10  20  10  20
# 1  30  40  30  40

# %% [markdown]
# #Dealing with Missing Values
# Let's load the dataset first, we can upload the data or can use the raw public link.

# %%
#df=df.drop(2,axis=0)

#or

#df.drop(2,axis=0,inplace=True)

# %%
df
# Out:
#         Day  Min_Temperature  Max_Temperature
# 0    Monday               18               25
# 1   Tuesday               20               28
# 3  Thursday               19               26
# 4    Friday               17               23

# %%
import pandas as pd

# %%
csv_url = 'https://raw.githubusercontent.com/yesdhruv/csv_files/master/heart.csv'
df = pd.read_csv(csv_url)
# Display the DataFrame
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# pd.read_csv()

# %% [markdown]
# ### General knowledge on Reading CSV Files
#  * CSV Format: Stands for Comma-Separated Values. A common format for storing tabular data where each value is separated by a comma.
#  * Reading CSV in Pandas: Use pd.read_csv('url/file_path') to read a CSV file into a DataFrame.
#  * Delimiter in CSV: The default delimiter is a comma. For tab-separated values (TSV), use delimiter='\t'.

# %% [markdown]
# ### Understanding Missing Values
#  * Missing Values in DataFrames
#    * Represented as NaN, indicating data is not available or not applicable.
#  * Importance
#    * Handling missing values is crucial before feeding data into machine learning algorithms.

# %% [markdown]
# * Applying isnull() and notnull() to the Entire DataFrame:
# This will give you a DataFrame where each cell is either True (if missing) or False.

# %%
# Using isnull() to identify missing values
missing_values = df.isnull()

# Using notnull() to identify non-missing values
non_missing_values = df.notnull()

# %%
non_missing_values
# Out:
#        age   sex    cp  trestbps  chol   fbs  restecg  thalach  exang  \
# 0     True  True  True      True  True  True     True     True   True
# 1     True  True  True      True  True  True     True     True   True
# 2     True  True  True      True  True  True     True     True   True
# 3     True  True  True      True  True  True     True     True   True
# 4     True  True  True      True  True  True     True     True   True
# ...    ...   ...   ...       ...   ...   ...      ...      ...    ...
# 1020  True  True  True      True  True  True     True     True   True
# 1021  True  True  True      True  True  True     True     True   True
# 1022  True  True  True      True  True  True     True     True   True
# 1023  True  True  True      True  True  True     True     True   True
# 1024  True  True  True      True  True  True     True     True   True
#
#       oldpeak  slope    ca  thal  target
# 0        True   True  True  True    True
# 1        True   True  True  True    True
# ...

# %%
# Assuming your DataFrame is named 'df'
# Count the number of zero values in each column
zero_counts = (df == 0).sum()

# %%
# Display the count of zero values for each column
print(zero_counts)
# Out:
# age           0
# sex         312
# cp          497
# trestbps      0
# chol          0
# fbs         872
# restecg     497
# thalach       0
# exang       680
# oldpeak     329
# slope        74
# ca          578
# thal          7
# target      499
# dtype: int64

# %%
# Count the total number of zero values in the entire DataFrame
total_zero_count = (df == 0).sum().sum()

# Display the total count of zero values
print(f'Total number of zero values: {total_zero_count}')
# Out:
# Total number of zero values: 4345

# %%
u= df['age'].value_counts()
len(u)
# Out:
# 41

# %%
df['age'].unique()
# Out:
# array([52, 53, 70, 61, 62, 58, 55, 46, 54, 71, 43, 34, 51, 50, 60, 67, 45,
#        63, 42, 44, 56, 57, 59, 64, 65, 41, 66, 38, 49, 48, 29, 37, 47, 68,
#        76, 40, 39, 77, 69, 35, 74])

# %% [markdown]
# ## Strategies for Handling Missing Data
#
# Two primary strategies for handling missing data are deletion and imputation.

# %% [markdown]
# ### Deletion Methods
#
# * Listwise Deletion
#  * Involves removing entire rows from a dataset if any value in the row is missing. This is a straightforward approach but can lead to significant data loss.
#
# * Pairwise Deletion
#  * Only the specific missing data point is omitted, not the entire row. Useful in statistical analyses like correlation, utilizing the remaining available data.

# %%
# Import NumPy and Pandas
import numpy as np
import pandas as pd

# Create a sample DataFrame with missing values
data = {
    'Name': ['Alice', 'Bob', 'Ali', 'David', 'Eva'],
    'Age': [25, 30, np.nan, 22, 28],
    'Salary': [50000, np.nan, 60000, 400,np.nan],
    'Department': ['HR', 'IT', 'Finance', np.nan, 'Marketing']
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame(data)
df
# Out:
#     Name   Age   Salary Department
# 0  Alice  25.0  50000.0         HR
# 1    Bob  30.0      NaN         IT
# 2    Ali   NaN  60000.0    Finance
# 3  David  22.0    400.0        NaN
# 4    Eva  28.0      NaN  Marketing

# %%
# Deletion: Listwise Deletion
df_listwise = df.dropna()
print("\nDataFrame after Listwise Deletion:")
df_listwise
# print(df_listwise)
# Out:
# DataFrame after Listwise Deletion:
#     Name   Age   Salary Department
# 0  Alice  25.0  50000.0         HR

# %%
# Deletion: Pairwise Deletion
df_pairwise = df.dropna(subset=['Name', 'Salary'])
print("\nDataFrame after Pairwise Deletion:")
df_pairwise
# Out:
# DataFrame after Pairwise Deletion:
#     Name   Age   Salary Department
# 0  Alice  25.0  50000.0         HR
# 2    Ali   NaN  60000.0    Finance
# 3  David  22.0    400.0        NaN

# %%
df.fillna(9)
# Out:
#     Name   Age   Salary Department
# 0  Alice  25.0  50000.0         HR
# 1    Bob  30.0      9.0         IT
# 2    Ali   9.0  60000.0    Finance
# 3  David  22.0    400.0          9
# 4    Eva  28.0      9.0  Marketing

# %% [markdown]
#  Pros and Cons of Deletion
# - Straightforward and easy to implement.
# - Can introduce bias, affecting the representativeness and reliability of the dataset.
# - Best suited for scenarios with minimal missing data or when the missing data is randomly distributed.

# %% [markdown]
# ### Imputation Methods
#
# * Mean/Median/Mode Imputation
#  * Involves replacing missing values with the mean, median, or mode of the respective column. Easy to implement and useful for quickly addressing missing data.
#
# <!-- * K-Nearest Neighbors (KNN) Imputation
#  * Utilizes the nearest neighbors of a missing data point to predict and impute its value. More sophisticated and can be more accurate than mean/median/mode imputation.
#
# * Multiple Imputation
#  * Involves creating multiple sets of imputations for missing values, providing a comprehensive approach by addressing the uncertainty inherent in any single imputation. -->
#
# #### Pros and Cons of Imputation
# - Helps in preserving the original size of the dataset.
# - Can introduce inaccuracies or biases if not implemented with an understanding of the dataset's characteristics.
# - Requires careful consideration of the nature of the missing data and the overall dataset structure.
# - Often preferred over deletion methods in scenarios where retaining the maximum amount of data is crucial.

# %%
# Imputation: Mean Imputation
df_mean_imputed = df.fillna(df.mean())
print("\nDataFrame after Mean Imputation:")
print(df_mean_imputed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-6bfeff784c72> in <cell line: 0>()
#       1 # Imputation: Mean Imputation
# ----> 2 df_mean_imputed = df.fillna(df.mean())
#       3 print("\nDataFrame after Mean Imputation:")
#       4 print(df_mean_imputed)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

# Sample DataFrame with missing values
data = {'A': [1, 2, np.nan, 4, 5],
        'B': [10, 20, 30, np.nan, 50],
        'C': [100, 200, 300, 400, 500]}

df = pd.DataFrame(data)

# %%
# Check for missing values in the DataFrame
if df.isnull().values.any():
    # Handling missing values by filling with the mean
    df_filled = df.fillna(df.mean())

    # Check if there are still any missing values
    if df_filled.isnull().values.any():
        raise ValueError("DataFrame still contains missing values. Check and handle missing values appropriately.")
else:
    df_filled = df.copy()  # No missing values, create a copy of the original DataFrame

# %%
# Check if the DataFrame contains numeric data
numeric_columns = df_filled.select_dtypes(include=[np.number]).columns
if len(numeric_columns) == 0:
    raise ValueError("DataFrame does not contain numeric columns. KNN imputation requires numeric data.")

# Imputation: K-Nearest Neighbors (KNN) Imputation
imputer = KNNImputer(n_neighbors=2)
df_knn_imputed = pd.DataFrame(imputer.fit_transform(df_filled), columns=df_filled.columns)

# %%
# Displaying Results
print("\nOriginal DataFrame:")
print(df)

print("\nDataFrame after Handling Missing Values:")
print(df_filled)

print("\nDataFrame after KNN Imputation:")
print(df_knn_imputed)
# Out:
# Original DataFrame:
#      A     B    C
# 0  1.0  10.0  100
# 1  2.0  20.0  200
# 2  NaN  30.0  300
# 3  4.0   NaN  400
# 4  5.0  50.0  500
#
# DataFrame after Handling Missing Values:
#      A     B    C
# 0  1.0  10.0  100
# 1  2.0  20.0  200
# 2  3.0  30.0  300
# 3  4.0  27.5  400
# 4  5.0  50.0  500
#
# DataFrame after KNN Imputation:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0  20.0  200.0
# 2  3.0  30.0  300.0
# 3  4.0  27.5  400.0
# 4  5.0  50.0  500.0

# %%
df
# Out:
#      A     B    C
# 0  1.0  10.0  100
# 1  2.0  20.0  200
# 2  NaN  30.0  300
# 3  4.0   NaN  400
# 4  5.0  50.0  500

# %% [markdown]
# #Exploratory Data Analysis (EDA)
#  - EDA involves examining and understanding the dataset's characteristics.
#  - Common EDA tasks include cleaning data, handling missing values, and adding useful columns.
#  - Example: Converting timestamps to datetime objects in Pandas for easier manipulation.

# %% [markdown]
# Importing the dataset of uber

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/yesdhruv/csv_files/master/Uber%20Request%20Data.csv'
data = pd.read_csv(url)
data
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (6745, 6)

# %%
data.columns
# Out:
# Index(['Request id', 'Pickup point', 'Driver id', 'Status',
#        'Request timestamp', 'Drop timestamp'],
#       dtype='object')

# %% [markdown]
# ###Data Cleaning and Manipulation

# %%
data
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %% [markdown]
# * Dropping Specific Rows
#  * data.drop Method: Used for removing specific rows from a DataFrame in pandas.
#
# * Labels vs. Index:
#  * Labels: Drop rows using index labels (non-numerical).
#  * Index: Drop rows by specifying their numerical index.

# %%
print(data.index)
# Out:
# RangeIndex(start=0, stop=6745, step=1)

# %%
# Assuming 'Request id' is the current index and you want to drop rows with specific labels
labels_to_drop = [0,1,2,4,6,7,8,9,10,15,6735, 6736, 6737, 6738, 6739, 6740, 6741, 6742, 6743, 6744]

# Drop rows based on labels using the 'labels' parameter
data.drop(labels=labels_to_drop, axis=0, inplace=False)

data
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
print(data.index)
# Out:
# RangeIndex(start=0, stop=6745, step=1)

# %%
data.drop(index=[3, 5], axis=0, inplace=True)
data
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 4     13-07-2016 08:33:16  13-07-2016 09:25:47
# ...

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/yesdhruv/csv_files/master/Uber%20Request%20Data.csv'

data = pd.read_csv(url)
data
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %% [markdown]
# * Renaming Column Names
#  * Removing Unwanted Characters

# %%
# Mapping:
# Original column names
original_columns = data.columns

# Define a mapping of old column names to new column names
column_mapping = {
    'Request id': 'reqUEST_Id',
    'Pickup point': 'pickUP_POINT',
    'Driver id': 'driVER_Id',
    'Status': 'sta-TUS',
    'Request timestamp': 'reqUEST_timeSTAMP',
    'Drop timestamp': 'drOP_timeSTAMP'
}

# Rename columns using the mapping
data.rename(columns=column_mapping, inplace=True)

updated_columns = data.columns

print("Updated Columns:",updated_columns)
# Out:
# Updated Columns: Index(['reqUEST_Id', 'pickUP_POINT', 'driVER_Id', 'sta-TUS',
#        'reqUEST_timeSTAMP', 'drOP_timeSTAMP'],
#       dtype='object')

# %%
# List Comprehension to remove asterisks from column names
data.columns = [col.replace('_', '+^^+') for col in data.columns]

# Display the DataFrame with updated column names
data
# Out:
#       reqUEST+^^+Id pickUP+^^+POINT  driVER+^^+Id            sta-TUS  \
# 0               619         Airport           1.0     Trip Completed
# 1               867         Airport           1.0     Trip Completed
# 2              1807            City           1.0     Trip Completed
# 3              2532         Airport           1.0     Trip Completed
# 4              3112            City           1.0     Trip Completed
# ...             ...             ...           ...                ...
# 6740           6745            City           NaN  No Cars Available
# 6741           6752         Airport           NaN  No Cars Available
# 6742           6751            City           NaN  No Cars Available
# 6743           6754            City           NaN  No Cars Available
# 6744           6753         Airport           NaN  No Cars Available
#
#      reqUEST+^^+timeSTAMP    drOP+^^+timeSTAMP
# 0         11/7/2016 11:51      11/7/2016 13:00
# ...

# %%
#Custom Function:
def remove_special_chars(column_name):
    return column_name.replace('reqUEST+^^+Id', 'reqID')

data.columns = [remove_special_chars(col) for col in data.columns]
# Display the DataFrame with updated column names
data
# Out:
#       reqID pickUP+^^+POINT  driVER+^^+Id            sta-TUS  \
# 0       619         Airport           1.0     Trip Completed
# 1       867         Airport           1.0     Trip Completed
# 2      1807            City           1.0     Trip Completed
# 3      2532         Airport           1.0     Trip Completed
# 4      3112            City           1.0     Trip Completed
# ...     ...             ...           ...                ...
# 6740   6745            City           NaN  No Cars Available
# 6741   6752         Airport           NaN  No Cars Available
# 6742   6751            City           NaN  No Cars Available
# 6743   6754            City           NaN  No Cars Available
# 6744   6753         Airport           NaN  No Cars Available
#
#      reqUEST+^^+timeSTAMP    drOP+^^+timeSTAMP
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %% [markdown]
# ###Working with DateTime

# %% [markdown]
# * pd.to_datetime Function: Converts a column containing date values into DateTime objects.

# %% [markdown]
# DateTime objects provide convenient methods to extract various attributes like year, month, day, day name, etc.

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/yesdhruv/csv_files/master/Uber%20Request%20Data.csv'

data = pd.read_csv(url)
data
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
print(data.columns.tolist())
# Out:
# ['Request id', 'Pickup point', 'Driver id', 'Status', 'Request timestamp', 'Drop timestamp']

# %%
data['Request timestamp'] = pd.to_datetime(data['Request timestamp'], dayfirst=True, errors='coerce')
data['Drop timestamp'] = pd.to_datetime(data['Drop timestamp'], dayfirst=True, errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  2674 non-null   datetime64[ns]
#  5   Drop timestamp     1150 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 316.3+ KB

# %%
data['Request timestamp']= pd.to_datetime(data['Request timestamp'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  6745 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.3+ KB
