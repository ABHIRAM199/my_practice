# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIRAM199/my_practice/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
csv_url ='https://raw.githubusercontent.com/yesdhruv/gapminder.csv/master/gapminder_data_graphs.csv'

# %%
df=pd.read_csv(csv_url)
#Display the data frame
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
df.shape
#will give the shape of the dataset
# Out:
# (3675, 8)

# %%
df.head() #understand the data set by seeing the fist five rows of data set
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6

# %%
df.head(25)  #shows first 25 elements in the dataset
# Out:
#         country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0   Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1   Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2   Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3   Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4   Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# 5   Afghanistan      Asia  2003      56.5      0.393       0.0509   346.0
# 6   Afghanistan      Asia  2004      57.1      0.409       0.0368   336.0
# 7   Afghanistan      Asia  2005      57.6      0.418       0.0515   360.0
# 8   Afghanistan      Asia  2006      58.0      0.429       0.0622   368.0
# 9   Afghanistan      Asia  2007      58.5      0.447       0.0838   409.0
# 10  Afghanistan      Asia  2008      59.2      0.447       0.1520   415.0
# 11  Afghanistan      Asia  2009      59.9      0.460       0.2380   492.0
# ...

# %%
df.tail()  #return last 5 rows
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3670  Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671  Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672  Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673  Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674  Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2

# %%
df.tail(20)
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3655  Zimbabwe    Africa  1999      48.5      0.437        1.330  1760.0
# 3656  Zimbabwe    Africa  2000      47.5      0.430        1.160  1700.0
# 3657  Zimbabwe    Africa  2001      47.0      0.431        1.050  1720.0
# 3658  Zimbabwe    Africa  2002      46.6      0.423        0.996  1560.0
# 3659  Zimbabwe    Africa  2003      46.4      0.414        0.886  1290.0
# 3660  Zimbabwe    Africa  2004      46.4      0.411        0.785  1210.0
# 3661  Zimbabwe    Africa  2005      46.8      0.411        0.887  1140.0
# 3662  Zimbabwe    Africa  2006      47.4      0.414        0.853  1090.0
# 3663  Zimbabwe    Africa  2007      48.2      0.421        0.803  1040.0
# 3664  Zimbabwe    Africa  2008      48.9      0.422        0.624   850.0
# 3665  Zimbabwe    Africa  2009      50.2      0.458        0.441   941.0
# 3666  Zimbabwe    Africa  2010      52.3      0.482        0.607  1110.0
# ...

# %%
df.info()  #gives all the datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3675 entries, 0 to 3674
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      3675 non-null   object
#  1   continent    3675 non-null   object
#  2   year         3675 non-null   int64
#  3   life_exp     3675 non-null   float64
#  4   hdi_index    3563 non-null   float64
#  5   co2_consump  3671 non-null   float64
#  6   gdp          3633 non-null   float64
#  7   services     3675 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 229.8+ KB

# %%
df.describe()   #useful for understanding the data and maths related to it
# Out:
#               year     life_exp    hdi_index  co2_consump            gdp  \
# count  3675.000000  3675.000000  3563.000000  3671.000000    3633.000000
# mean   2008.000000    69.849306     0.674864     4.712731   11966.053675
# std       6.056125     8.886563     0.164834     6.567435   17105.787953
# min    1998.000000    32.500000     0.255000     0.015900     238.000000
# 25%    2003.000000    63.900000     0.537500     0.560500    1470.000000
# 50%    2008.000000    71.700000     0.699000     2.250000    4280.000000
# 75%    2013.000000    76.400000     0.805000     6.615000   13600.000000
# max    2018.000000    84.800000     0.956000    67.100000  105000.000000
#
#           services
# count  3675.000000
# mean     51.248705
# std      18.312501
# min       5.590000
# 25%      37.600000
# 50%      52.900000
# 75%      65.700000
# max      88.500000

# %%
df['life_exp']    #access a single column
# Out:
# 0       53.3
# 1       54.7
# 2       54.7
# 3       54.8
# 4       55.5
#         ...
# 3670    58.0
# 3671    58.6
# 3672    59.2
# 3673    59.9
# 3674    60.6
# Name: life_exp, Length: 3675, dtype: float64

# %%
df[['gdp','year','hdi_index']]   #access multiple column and graphs tables related to the columns data
# Out:
#          gdp  year  hdi_index
# 0        NaN  1998      0.344
# 1        NaN  1999      0.348
# 2        NaN  2000      0.350
# 3        NaN  2001      0.353
# 4      333.0  2002      0.384
# ...      ...   ...        ...
# 3670  1440.0  2014      0.547
# 3671  1450.0  2015      0.553
# 3672  1430.0  2016      0.558
# 3673  1480.0  2017      0.563
# 3674  1510.0  2018      0.569
#
# [3675 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='object')

# %%
df.drop('services',axis=1) #if you put inplace=True the column will get permenently delete from the dataframe
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
# [3675 rows x 7 columns]

# %%
df.dropna()   #for deleting the rows which has the null values
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# 5     Afghanistan      Asia  2003      56.5      0.393       0.0509   346.0
# 6     Afghanistan      Asia  2004      57.1      0.409       0.0368   336.0
# 7     Afghanistan      Asia  2005      57.6      0.418       0.0515   360.0
# 8     Afghanistan      Asia  2006      58.0      0.429       0.0622   368.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 4         25.6
# 5         25.9
# ...

# %%
#operations
df['life_exp'].sum()
df['life_exp'].min()
df['life_exp'].max()
# Out:
# 84.8

# %%
df['life_exp'].mean()
# Out:
# 69.84930612244898

# %%
#accessing the data row wise
#loc[] --> Acess data from labels
#iloc[] --> Acess data from indices

# %%
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
df.loc[2]
# Out:
# country        Afghanistan
# continent             Asia
# year                  2000
# life_exp              54.7
# hdi_index             0.35
# co2_consump          0.037
# gdp                    NaN
# services              24.7
# Name: 2, dtype: object

# %%
df.iloc[4]
# Out:
# country        Afghanistan
# continent             Asia
# year                  2002
# life_exp              55.5
# hdi_index            0.384
# co2_consump         0.0471
# gdp                  333.0
# services              25.6
# Name: 4, dtype: object

# %%
df.dropna(inplace=True)

# %%
df.loc[4]
# Out:
# country        Afghanistan
# continent             Asia
# year                  2002
# life_exp              55.5
# hdi_index            0.384
# co2_consump         0.0471
# gdp                  333.0
# services              25.6
# Name: 4, dtype: object

# %%
df.iloc[4]
# Out:
# country        Afghanistan
# continent             Asia
# year                  2006
# life_exp              58.0
# hdi_index            0.429
# co2_consump         0.0622
# gdp                  368.0
# services              26.9
# Name: 8, dtype: object

# %%
df.iloc[2,4]  #second row and fourth column
# Out:
# 0.409

# %%
df.loc[5,'life_exp'] #loc works not based on indices so column name should be passed in loc
# Out:
# 56.5

# %%
df=pd.read_csv(csv_url)
#Display the data frame
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
df.loc[1:5] #normally in python 5 is not included but in loc 1 to 5 is included
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 5  Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
#
#    services
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6
# 5      25.9

# %%
df.iloc[1:5]    #in iloc 5 is not included
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
#
#    services
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6

# %%
df=pd.read_csv(csv_url)
#Display the data frame
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
col =df['life_exp'] #23/01/2024
col
# Out:
# 0       53.3
# 1       54.7
# 2       54.7
# 3       54.8
# 4       55.5
#         ...
# 3670    58.0
# 3671    58.6
# 3672    59.2
# 3673    59.9
# 3674    60.6
# Name: life_exp, Length: 3675, dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-33-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# year            2008.000000
# life_exp          69.849306
# hdi_index          0.674864
# co2_consump        4.712731
# gdp            11966.053675
# services          51.248705
# dtype: float64

# %%
df['life_exp'].mean()
# Out:
# 69.84930612244898

# %%
df[(df['life_exp']>30)&(df['life_exp']<40)]
# Out:
#      country      continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 1419   Haiti  North America  2010      32.5      0.471        0.211  1290.0
#
#       services
# 1419      59.9

# %%
df[df['life_exp']>84]
# Out:
#                country continent  year  life_exp  hdi_index  co2_consump  \
# 1468  Hong Kong, China      Asia  2017      84.1      0.941         5.92
# 1469  Hong Kong, China      Asia  2018      84.3      0.946         5.86
# 1696             Japan      Asia  2014      84.1      0.906         9.88
# 1697             Japan      Asia  2015      84.3      0.908         9.58
# 1698             Japan      Asia  2016      84.5      0.912         9.45
# 1699             Japan      Asia  2017      84.7      0.915         9.33
# 1700             Japan      Asia  2018      84.8      0.917         9.14
# 2915         Singapore      Asia  2015      84.1      0.931        11.00
# 2916         Singapore      Asia  2016      84.4      0.935         6.64
# 2917         Singapore      Asia  2017      84.7      0.933         7.11
# 2918         Singapore      Asia  2018      84.7      0.936         7.10
#
#           gdp  services
# 1468  44400.0      88.3
# 1469  45300.0      88.5
# ...

# %%
#group data
print(df.groupby('continent')['life_exp'].min())
# Out:
# continent
# Africa           43.1
# Asia             53.3
# Europe           65.0
# North America    32.5
# Oceania          56.8
# South America    63.5
# Name: life_exp, dtype: float64

# %%
df.groupby('continent')['life_exp'].max()
# Out:
# continent
# Africa           77.5
# Asia             84.8
# Europe           84.0
# North America    82.4
# Oceania          83.0
# South America    80.1
# Name: life_exp, dtype: float64

# %%
df.groupby('country')['life_exp'].mean()
# Out:
# country
# Afghanistan    58.857143
# Albania        77.080952
# Algeria        73.571429
# Angola         58.438095
# Argentina      75.404762
#                  ...
# Vanuatu        64.219048
# Vietnam        73.071429
# Yemen          66.171429
# Zambia         53.366667
# Zimbabwe       51.895238
# Name: life_exp, Length: 175, dtype: float64

# %%
#find the minimum life expectancy in INDIA

df_india=df[df['country']=="India"]
df_india.min()
# Out:
# country        India
# continent       Asia
# year            1998
# life_exp        62.1
# hdi_index      0.481
# co2_consump    0.916
# gdp            695.0
# services        23.4
# dtype: object

# %%
df_india['life_exp'].min() #only return min life exp in India
# Out:
# 62.1

# %%
#calculate avg life exp in the world every year

df.groupby('year')['life_exp'].mean()
# Out:
# year
# 1998    66.912000
# 1999    67.125714
# 2000    67.410286
# 2001    67.676000
# 2002    67.873714
# 2003    68.094286
# 2004    68.371429
# 2005    68.735429
# 2006    69.122857
# 2007    69.516571
# 2008    69.850286
# 2009    70.217714
# 2010    70.473143
# 2011    70.967429
# 2012    71.312571
# 2013    71.607429
# 2014    71.804000
# 2015    72.045143
# 2016    72.324000
# 2017    72.584571
# 2018    72.810857
# Name: life_exp, dtype: float64

# %%
#avg life exp in India every year

df_india.groupby('year')['life_exp'].mean()
# Out:
# year
# 1998    62.1
# 1999    62.6
# 2000    62.9
# 2001    63.3
# 2002    63.8
# 2003    64.5
# 2004    65.2
# 2005    65.4
# 2006    65.6
# 2007    65.8
# 2008    66.1
# 2009    66.8
# 2010    67.3
# 2011    67.6
# 2012    68.0
# 2013    68.4
# 2014    69.0
# 2015    69.4
# 2016    70.0
# 2017    70.3
# 2018    70.5
# Name: life_exp, dtype: float64

# %%
#count the number of countries in each continent
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa           51
# Asia             47
# Europe           39
# North America    19
# Oceania           8
# South America    11
# Name: country, dtype: int64

# %%
df.groupby(['continent','year'])['life_exp'].mean()
# Out:
# continent      year
# Africa         1998    56.111765
#                1999    56.250980
#                2000    56.401961
#                2001    56.658824
#                2002    56.894118
#                          ...
# South America  2014    75.300000
#                2015    75.445455
#                2016    75.500000
#                2017    75.654545
#                2018    75.827273
# Name: life_exp, Length: 126, dtype: float64

# %%
#Soring the data

df.sort_values('co2_consump')
# Out:
#                country continent  year  life_exp  hdi_index  co2_consump  \
# 759   Congo, Dem. Rep.    Africa  2001      54.2      0.350       0.0159
# 760   Congo, Dem. Rep.    Africa  2002      54.4      0.358       0.0171
# 758   Congo, Dem. Rep.    Africa  2000      53.9      0.349       0.0190
# 761   Congo, Dem. Rep.    Africa  2003      54.8      0.366       0.0202
# 532            Burundi    Africa  2005      50.3      0.337       0.0209
# ...                ...       ...   ...       ...        ...          ...
# 2691             Qatar      Asia  2001      71.5      0.817      67.1000
# 3276       Timor-Leste      Asia  1998      63.8        NaN          NaN
# 3277       Timor-Leste      Asia  1999      58.5        NaN          NaN
# 3278       Timor-Leste      Asia  2000      65.5      0.484          NaN
# 3279       Timor-Leste      Asia  2001      65.8      0.492          NaN
#
#           gdp  services
# 759     334.0     18.50
# 760     334.0     18.70
# ...

# %%
df.sort_values('co2_consump',ascending=False).sort_values('country',ascending=True)
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 9     Afghanistan      Asia  2007      58.5      0.447       0.0838   409.0
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# 15    Afghanistan      Asia  2013      61.9      0.496       0.2800   592.0
# 6     Afghanistan      Asia  2004      57.1      0.409       0.0368   336.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3658     Zimbabwe    Africa  2002      46.6      0.423       0.9960  1560.0
# 3656     Zimbabwe    Africa  2000      47.5      0.430       1.1600  1700.0
# 3655     Zimbabwe    Africa  1999      48.5      0.437       1.3300  1760.0
# 3665     Zimbabwe    Africa  2009      50.2      0.458       0.4410   941.0
#
#       services
# 1         24.6
# 9         27.7
# ...

# %%
#sort the data first by life expectancy in asc order and then by year in desc order

df.sort_values(by=['life_exp','year'],ascending=[True,False])
# Out:
#                        country      continent  year  life_exp  hdi_index  \
# 1419                     Haiti  North America  2010      32.5      0.471
# 1098                  Eswatini         Africa  2004      43.1      0.445
# 1099                  Eswatini         Africa  2005      43.3      0.456
# 632   Central African Republic         Africa  2000      43.8      0.325
# 631   Central African Republic         Africa  1999      43.8      0.323
# ...                        ...            ...   ...       ...        ...
# 1698                     Japan           Asia  2016      84.5      0.912
# 2918                 Singapore           Asia  2018      84.7      0.936
# 1699                     Japan           Asia  2017      84.7      0.915
# 2917                 Singapore           Asia  2017      84.7      0.933
# 1700                     Japan           Asia  2018      84.8      0.917
#
#       co2_consump      gdp  services
# 1419       0.2110   1290.0      59.9
# ...

# %%
#comparison can be done with strings also
df[df['country']>'Y']
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3612     Yemen      Asia  1998      62.5      0.431        0.734  2290.0
# 3613     Yemen      Asia  1999      63.0      0.435        0.812  2310.0
# 3614     Yemen      Asia  2000      63.5      0.444        0.832  2380.0
# 3615     Yemen      Asia  2001      64.0      0.453        0.895  2400.0
# 3616     Yemen      Asia  2002      64.5      0.461        0.844  2430.0
# ...        ...       ...   ...       ...        ...          ...     ...
# 3670  Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671  Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672  Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673  Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674  Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 3612      41.1
# 3613      42.9
# 3614      44.8
# 3615      46.9
# ...

# %%
xyz=df.drop(2,axis=0)

# %%
xyz.head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 5  Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
#
#    services
# 0      24.4
# 1      24.6
# 3      24.7
# 4      25.6
# 5      25.9

# %%
xyz.reset_index(drop=True).head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 3  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 4  Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      25.6
# 4      25.9

# %%
df.drop(2,inplace=True)
df.head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 5  Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
#
#    services
# 0      24.4
# 1      24.6
# 3      24.7
# 4      25.6
# 5      25.9

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 3  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 4  Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      25.6
# 4      25.9
